# %% [markdown]
# # Ejercicio 1
#
# Desarrolle una aplicación que calcule el factorial de un numero entero introducido por teclado.

# %%
n = int(input("Ingrese un número: "))

fact = 1

for i in range(1, n+1):
  fact *= i

print(f"El factorial de {n} es {fact}")
# Out:
# El factorial de 5 es 120

# %% [markdown]
# # Ejercicio 3
#
# Desarrolle una aplicación que permita ingresar diferentes números por teclado con un limite definido inicialmente (no menor a 3 números) y determine cual de ellos es el mayor y el menor.

# %%
while True:
  n = int(input("Ingrese la cantidad de numeros que desea ingresar (no menor a 3): "))
  if n >= 3:
    break
  else:
    print("El numero ingresado es menor a 3")

inputs = []

for i in range (n):
  num = int(input(f"Ingrese el numero {i+1}: "))
  inputs.append(num)
  if i == 0:
    mayor = num
    menor = num
  else:
    if num > mayor:
      mayor = num
    if num < menor:
      menor = num

print('Los numeros ingresados son:', inputs)
print(f"El numero mayor es: {mayor}")
print(f"El numero menor es: {menor}")
# Out:
# Los numeros ingresados son: [1, 2, 3]
# El numero mayor es: 3
# El numero menor es: 1

# %% [markdown]
# # Ejercicio 4
#
# Desarrolle una aplicación que permita identificar si una cadena introducida por teclado es un palíndromo (oso es palíndromo).

# %%
def esPalindromo(palabra):
  inverso = ""
  for letra in palabra:
    inverso = letra + inverso
  return inverso == palabra

cadena = input("Introduce una cadena de texto: ")

if (esPalindromo(cadena)):
  print(f'La cadena "{cadena}" es un palíndromo.')
else:
  print(f'La cadena "{cadena}" no es un palíndromo.')
# Out:
# La cadena "oso" es un palíndromo.

# %% [markdown]
# # Ejercicio 5
#
# Desarrolle una aplicación que permita introducir 7 números por teclado y determine cual de ellos se repite más veces y cuantas.

# %%
numeros = {}

entradas = []

for i in range(7):
  num = int(input(f"Ingrese el número {i + 1}: "))
  entradas.append(num)
  numeros[num] = numeros.get(num, 0) + 1

numMax = 0
cantMax = 0

first = True

for num, cant in numeros.items():
  if first:
    numMax = num
    cantMax = cant
    first = False
  elif cant > cantMax:
    numMax = num
    cantMax = cant

print(f"Los números ingresados son: {entradas}")
print(f"El número que más veces se repite es {numMax} con {cantMax} repeticiones")
# Out:
# Los números ingresados son: [1, 1, 1, 1, 2, 3, 4]
# El número que más veces se repite es 1 con 4 repeticiones

# %% [markdown]
# # Ejercicio 7
#
# Desarrolla una aplicación que ordene números a través del método burbuja.

# %%
def ordenarBurbuja(arreglo):
  n = len(arreglo)
  for i in range(n - 1):
    for j in range(n - 1 - i):
      if arreglo[j] > arreglo[j+1]:
        arreglo[j], arreglo[j+1] = arreglo[j+1], arreglo[j]

arreglo = [64, 34, 25, 12, 22, 11, 90]
print(f"Arreglo original: {arreglo}")
ordenarBurbuja(arreglo)
print(f"Arreglo ordenado: {arreglo}")
# Out:
# Arreglo original: [64, 34, 25, 12, 22, 11, 90]
# Arreglo ordenado: [11, 12, 22, 25, 34, 64, 90]
