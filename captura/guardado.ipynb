# %% [markdown]
# # Otro uso de matplotlib

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img_bgr = cv2.imread('images/2.png')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)

print('Alto:', img_bgr.shape[0])
print('Ancho:', img_bgr.shape[1])
print('Canales:', img_bgr.shape[2])

# Another way to use subplot
fig,axs = plt.subplots(1, 4, figsize=(20, 5))

axs[0].imshow(img_rgb)
axs[0].set_title('Imagen Original')
# axs[0].axis('off')

fig_img = axs[1].imshow(img_rgb[...,0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1], shrink=0.5)
axs[1].set_title('Canal Rojo')
axs[1].axis('off')

fig_img = axs[2].imshow(img_rgb[...,1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2], shrink=0.5)
axs[2].set_title('Canal Verde')
axs[2].axis('off')

fig_img = axs[3].imshow(img_rgb[...,2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3], shrink=0.5)
axs[3].set_title('Canal Azul')
axs[3].axis('off')
# Out:
# Alto: 577
# Ancho: 433
# Canales: 3
# (-0.5, 432.5, 576.5, -0.5)

# %%
plt.imshow(img_rgb[:200, :200, :])

# %%
cv2.imwrite('images/2-bgr.png', img_bgr)
plt.imsave('images/2-bgrtorgb.png', cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
