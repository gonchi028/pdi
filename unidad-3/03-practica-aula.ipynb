# %% [markdown]
# # Aliasing y los patrones de moire
#
# El aliasing de una imagen es un fenómeno visual en la imagen digital donde una representación muestreada presenta artefactos o distorsiones indeseables. Estos artefactos suelen aparecer como bordes irregulares (jagged) o escalonados ("stair-stepped"), lo que puede reducir significativamente la calidad y el detalle general de la imagen. La causa principal del aliasing de imagen son las limitaciones de los sensores o pantallas digitales, que se componen de píxeles discretos. Cuando una imagen se captura o se muestra con un número limitado de píxeles, el contenido de alta frecuencia (como líneas finas, texturas o patrones intrincados) puede resultar difícil de resolver, lo que resulta en aliasing.
#
# El aliasing no se limita a un único artefacto visual; también incluye efectos como patrones de Moiré (patrones extraños en forma de ondas o remolinos) y ruido de color (cambios de color aleatorios). Además, el aliasing puede ocurrir no solo en el espacio (aliasing espacial) sino también en el tiempo (aliasing temporal), como en vídeos o animaciones, donde el movimiento se ve brusco o poco natural. Estos problemas surgen debido a la interpretación errónea de frecuencias superiores a la mitad de la frecuencia de muestreo, lo que provoca que se perciban como frecuencias más bajas. Este fenómeno, resultado del submuestreo, puede hacer que las señales o los detalles sean indistinguibles, lo que genera errores de medición en las imágenes digitales.
#
# ### Patron de Moiré
#
# El efecto moiré es un patrón de interferencia que se forma cuando se superponen dos rejillas de líneas, ya sean rectas o curvas, con un cierto ángulo. O cuando las rejillas tienen tamaños ligeramente diferentes.
#
# ![image.png](attachment:image.png)
#
# Fuente: https://cloudinary.com/glossary/image-aliasing#:~:text=Image%20aliasing%20is%20a%20visual,and%20detail%20in%20the%20image.

# %% [markdown]
# # Contrarestando los efectos

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img1 = cv2.imread('./images/img-p1.jpeg', 0)
img2 = cv2.imread('./images/img-p2.jpeg', 0)
img3 = cv2.imread('./images/img-p3.jpeg', 0)

def convolucion_media_horizontal(imagen, tamanioKernel):
  kernel = np.ones((1, tamanioKernel), np.float32) / tamanioKernel
  img_final = cv2.filter2D(imagen, -1, kernel)
  return img_final

def convolucion_media_vertical(imagen, tamanioKernel):
  kernel = np.ones()

# kernel horizontal
kernel_horizontal = np.array(
  [[1, 2, 1],
   [2, 4, 2],
   [1, 2, 1]])

img_resultado_1 = cv2.filter2D(img1, -1, kernel_horizontal)

img_resultado_3 = convolucion_media_horizontal(img3, 17)
   

plt.figure(figsize=(15, 10))

plt.subplot(3, 2, 1)
plt.title('Imagen original')
plt.imshow(img1, cmap='gray')
plt.axis('off')

# plt.subplot(3, 2, 2)
# plt.title('Resultado')
# plt.imshow(img_resultado, cmap='gray')
# plt.axis('off')

plt.subplot(3, 2, 3)
plt.title('Imagen original')
plt.imshow(img_gris, cmap='gray')
plt.axis('off')

# plt.subplot(3, 2, 4)
# plt.title('Resultado')
# plt.imshow(img_resultado, cmap='gray')
# plt.axis('off')

plt.subplot(3, 2, 5)
plt.title('Imagen original')
plt.imshow(img_gris, cmap='gray')
plt.axis('off')

# plt.subplot(3, 2, 6)
# plt.title('Resultado')
# plt.imshow(img_resultado, cmap='gray')
# plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/__init__.py:23
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/multiarray.py:10
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/overrides.py:7
#       6 from .._utils._inspect import getargspec
# ----> 7 from numpy._core._multiarray_umath import (
#       8     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      11 ARRAY_FUNCTIONS = set()
#
# ImportError: dlopen(/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/_multiarray_umath.cpython-310-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/gonzaloquispe/miniconda3/envs/pdi/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/__init__.py:114
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/__config__.py:4
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/__init__.py:49
#      26     msg = """
#      27
#      28 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)
#      47 """ % (sys.version_info[0], sys.version_info[1], sys.executable,
#      48         __version__, exc)
# ---> 49     raise ImportError(msg)
#      50 finally:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python3.10 from "/Users/gonzaloquispe/miniconda3/envs/pdi/bin/python"
#   * The NumPy version is: "2.2.4"
#
# and make sure that they are the versions you expect.
# Please carefully study the documentation linked above for further help.
#
# Original error was: dlopen(/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/_multiarray_umath.cpython-310-darwin.so, 0x0002): Library not loaded: @rpath/libgfortran.5.dylib
#   Referenced from: <C435405B-BFF1-399F-A1EC-BD43418F546A> /Users/gonzaloquispe/miniconda3/envs/pdi/lib/libopenblas.0.dylib
#   Reason: tried: '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/_core/../../../../libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/Users/gonzaloquispe/miniconda3/envs/pdi/bin/../lib/libgfortran.5.dylib' (duplicate LC_RPATH '@loader_path'), '/usr/local/lib/libgfortran.5.dylib' (no such file), '/usr/lib/libgfortran.5.dylib' (no such file, not in dyld cache)
#
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# File ~/miniconda3/envs/pdi/lib/python3.10/site-packages/numpy/__init__.py:119
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
#     117     its source directory; please exit the numpy source tree, and relaunch
#     118     your python interpreter from there."""
# --> 119     raise ImportError(msg) from e
#     121 from . import _core
#     122 from ._core import (
#     123     False_, ScalarType, True_,
#     124     abs, absolute, acos, acosh, add, all, allclose,
#    (...)
#     169     vecmat, void, vstack, where, zeros, zeros_like
#     170 )
#
# ImportError: Error importing numpy: you should not try to import numpy from
#         its source directory; please exit the numpy source tree, and relaunch
#         your python interpreter from there.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ImportError: numpy._core.multiarray failed to import
